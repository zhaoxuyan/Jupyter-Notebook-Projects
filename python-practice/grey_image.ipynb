# %%
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image

# %matplotlib inline
I = Image.open('/Users/zhaoxuyan/Desktop/taaarannn.png', 'r')
imshow(np.asarray(I))

# %%
L = I.convert('L')   #转化为灰度图
imshow(np.asarray(L))
L.show()
