# %%
# %matplotlib inline
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image


im = Image.open('/Users/zhaoxuyan/Documents/多媒体技术/实验二/taaarannn.bmp')
imshow(np.asarray(im))

# %%
hsv = im.convert('HSV')
imshow(np.asarray(hsv))

# %%
yuv = im.convert('YUV')
imshow(np.asarray(yuv))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-80641b9cba3f> in <module>()
# ----> 1 yuv = im.convert('YUV')
#       2 imshow(np.asarray(yuv))
#
# /Users/zhaoxuyan/anaconda/lib/python2.7/site-packages/PIL/Image.pyc in convert(self, mode, matrix, dither, palette, colors)
#     952                 # normalize source image and try again
#     953                 im = self.im.convert(getmodebase(self.mode))
# --> 954                 im = im.convert(mode, dither)
#     955             except KeyError:
#     956                 raise ValueError("illegal conversion")
#
# ValueError: conversion from RGB to YUV not supported
